# %%
import numpy as np
import pandas as pd
import os
os.chdir('C:/Users/박지원')
import matplotlib.pyplot as plt  
from matplotlib import font_manager, rc 
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %%
car=pd.read_csv('car.csv',encoding='cp949')
month_2016=pd.read_csv('month2016.csv',encoding='cp949')
rule=pd.read_csv('rule.csv',encoding='cp949')
road=pd.read_csv('road.csv',encoding='cp949')
age=pd.read_csv('age.csv', encoding='cp949')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-5f5d0492fad2> in <module>
#       1 #car=pd.read_csv('car.csv',encoding='cp949')
# ----> 2 month_2016=pd.read_csv('month2016.csv',encoding='cp949')
#       3 rule=pd.read_csv('rule.csv',encoding='cp949')
#       4 road=pd.read_csv('road.csv',encoding='cp949')
#       5 age=pd.read_csv('age.csv', encoding='cp949')
#
# ...

# %%
car.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-88f6e08b7bc1> in <module>
# ----> 1 car.head(2)
#
# NameError: name 'car' is not defined

# %%
month_2016.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-786ef0e6a40d> in <module>
# ----> 1 month_2016.head(2)
#
# NameError: name 'month_2016' is not defined

# %%
age.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-22dcafbc5a76> in <module>
# ----> 1 age.head(2)
#
# NameError: name 'age' is not defined

# %%
rule.head(2)
# Out:
#   사고유형대분류 사고유형    법규위반  발생건수
# 0    차대사람  횡단중      과속   152
# 1    차대사람  횡단중  중앙선 침범   314

# %%
road.head(2)
# Out:
#   사고유형대분류 사고유형  도로종류  발생건수
# 0    차대사람  횡단중  일반국도  1075
# 1    차대사람  횡단중   지방도  1904

# %%
fig = plt.figure( figsize = (60, 50))   # 차대사람
plt.subplot(3, 2, 1)
plt.bar(car.loc[0:9, '차종'], car.loc[0:9, '발생건수'])
plt.title('횡단중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 2)
plt.bar(car.loc[10:19, '차종'], car.loc[10:19, '발생건수'])
plt.title('차도통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 3)
plt.bar(car.loc[20:29, '차종'], car.loc[20:29, '발생건수'])
plt.title('길가장자리 구역 통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 4)
plt.bar(car.loc[30:39, '차종'], car.loc[30:39, '발생건수'])
plt.title('보도통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 5)
plt.bar(car.loc[40:49, '차종'], car.loc[40:49, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

fig.suptitle('차대사람', fontsize=100)
plt.show()

# %%
fig = plt.figure( figsize = (60, 50))   #차대차
plt.subplot(2, 2, 1)
plt.bar(car.loc[50:59, '차종'], car.loc[50:59, '발생건수'])
plt.title('정면충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(2, 2, 2)
plt.bar(car.loc[60:69, '차종'], car.loc[60:69, '발생건수'])
plt.title('측면충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(2, 2, 3)
plt.bar(car.loc[70:79, '차종'], car.loc[70:79, '발생건수'])
plt.title('추돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(2, 2, 4)
plt.bar(car.loc[80:89, '차종'], car.loc[80:89, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
fig.suptitle('차대차', fontsize=100)
plt.show()

# %%
fig = plt.figure( figsize = (60, 50))   #차량단독
plt.subplot(3, 2, 1)
plt.bar(car.loc[90:99, '차종'], car.loc[90:99, '발생건수'])
plt.title('전도전복', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 2)
plt.bar(car.loc[100:109, '차종'], car.loc[100:109, '발생건수'])
plt.title('공작물충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 3)
plt.bar(car.loc[110:115, '차종'], car.loc[110:115, '발생건수'])
plt.title('주/정차 차량 충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 4)
plt.bar(car.loc[116:125, '차종'], car.loc[116:125, '발생건수'])
plt.title('도로이탈', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 5)
plt.bar(car.loc[126:135, '차종'], car.loc[126:135, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

fig.suptitle('차량단독', fontsize=100)
plt.show()

# %%
plt.bar(car.loc[136:138, '차종'], car.loc[136:138, '발생건수'])  #철길건널목
plt.title('철길건널목 \n기타', fontsize=20)
plt.show()

# %%
car1 = car.loc[0:9, '발생건수'].sum()   #차대사람
car2 = car.loc[10:19, '발생건수'].sum()
car3 = car.loc[20:29, '발생건수'].sum()
car4 = car.loc[30:39, '발생건수'].sum()
car5 = car.loc[40:49, '발생건수'].sum()
car6 = car.loc[50:59, '발생건수'].sum()
car7 = car.loc[60:69, '발생건수'].sum()
car8 = car.loc[70:79, '발생건수'].sum()
car9 = car.loc[80:89, '발생건수'].sum()
car10 = car.loc[90:99, '발생건수'].sum()
car11= car.loc[100:109, '발생건수'].sum()
car12 = car.loc[110:115, '발생건수'].sum()
car13 = car.loc[116:125, '발생건수'].sum()
car14 = car.loc[126:135, '발생건수'].sum()
car15 = car.loc[136:138, '발생건수'].sum()

# %%
cp = pd.DataFrame({'type': ['횡단중', '차도통행중', '길가장자리', '보도통행중', '기타'],
                  'event': [car1, car2, car3, car4, car5]})
cp
# Out:
#     type  event
# 0    횡단중  33884
# 1  차도통행중   3622
# 2  길가장자리   3544
# 3  보도통행중   1627
# 4     기타  14743

# %%
cc = pd.DataFrame({'type': ['정면충돌', '측면충돌', '추돌', '기타'],
                  'event': [car6, car7, car8, car9]})
cc
# Out:
#    type  event
# 0  정면충돌  19498
# 1  측면충돌  73397
# 2    추돌  41003
# 3    기타  28091

# %%
co = pd.DataFrame({'type': ['전도전복', '공작물충돌', '주/정차 차량충돌', '도로이탈','기타'],
                  'event': [car10, car11, car12, car13, car14]})
co
# Out:
#         type  event
# 0       전도전복   4834
# 1      공작물충돌   2160
# 2  주/정차 차량충돌     36
# 3       도로이탈    261
# 4         기타   3100

# %%
fe = pd.DataFrame({'type': ['기타'],
                  'event': [car15]})
fe
# Out:
#   type  event
# 0   기타      6

# %%
fig = plt.figure( figsize = (60, 50))   # 차대사람
plt.subplot(2, 2, 1)
plt.bar(cp.type, cp.event)
plt.title('차대사람', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(2, 2, 2)
plt.bar(cc.type, cc.event)
plt.title('차대차', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(2, 2, 3)
plt.bar(co.type, co.event)
plt.title('길가장자리 구역 통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(2, 2, 4)
plt.bar(fe.type, fe.event)
plt.title('보도통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

fig.suptitle('사고유형별 발생건수', fontsize=100)
plt.show()

# %%
fig = plt.figure( figsize = (60, 50))   # 차대사람
plt.subplot(3, 2, 1)
plt.bar(rule.loc[0:7, '법규위반'], rule.loc[0:7, '발생건수'])
plt.title('횡단중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 2)
plt.bar(rule.loc[8:15, '법규위반'], rule.loc[8:15, '발생건수'])
plt.title('차도통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 3)
plt.bar(rule.loc[16:23, '법규위반'], rule.loc[16:23, '발생건수'])
plt.title('길가장자리 구역 통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 4)
plt.bar(rule.loc[24:31, '법규위반'], rule.loc[24:31, '발생건수'])
plt.title('보도통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 5)
plt.bar(rule.loc[32:39, '법규위반'], rule.loc[32:39, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

fig.suptitle('차대사람', fontsize=100)
plt.show()

# %%
fig = plt.figure( figsize = (60, 50))   # 차대사람
plt.subplot(2, 2, 1)
plt.bar(rule.loc[40:47, '법규위반'], rule.loc[40:47, '발생건수'])
plt.title('정면충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(2, 2, 2)
plt.bar(rule.loc[48:55, '법규위반'], rule.loc[48:55, '발생건수'])
plt.title('측면충돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(2, 2, 3)
plt.bar(rule.loc[56:63, '법규위반'], rule.loc[56:63, '발생건수'])
plt.title('추돌', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(2, 2, 4)
plt.bar(rule.loc[64:71, '법규위반'], rule.loc[64:71, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

fig.suptitle('차대차', fontsize=100)
plt.show()

# %%
fig = plt.figure( figsize = (60, 50))   # 차량단독 해야함!!!!!!!!!!!!!!!!!!!!!!
plt.subplot(3, 2, 1)
plt.bar(rule.loc[0:7, '법규위반'], rule.loc[0:7, '발생건수'])
plt.title('횡단중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 2)
plt.bar(rule.loc[8:15, '법규위반'], rule.loc[8:15, '발생건수'])
plt.title('차도통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 3)
plt.bar(rule.loc[16:23, '법규위반'], rule.loc[16:23, '발생건수'])
plt.title('길가장자리 구역 통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 4)
plt.bar(rule.loc[24:31, '법규위반'], rule.loc[24:31, '발생건수'])
plt.title('보도통행중', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)
plt.subplot(3, 2, 5)
plt.bar(rule.loc[32:39, '법규위반'], rule.loc[32:39, '발생건수'])
plt.title('기타', fontsize=70)
plt.xticks(fontsize=27)
plt.yticks(fontsize=40)

fig.suptitle('차대사람', fontsize=100)
plt.show()
